# %%
1380+1
# Out:
# 1381

# %%
1380/2
# Out:
# 690.0

# %%
poem = """
І небо невмите, і заспані хвилі
І понад берегом геть-геть,
Неначе пяний, очерет
Без вітру гнеться. Боже милий
"""
print(poem)
# Out:
# І небо невмите, і заспані хвилі
# І понад берегом геть-геть,
# Неначе пяний, очерет
# Без вітру гнеться. Боже милий

# %% [markdown]
# І небо невмите, і заспані хвилі
# І понад берегом "геть-геть",
# --------------------------------
# Неначе *пяний*, очерет
# Без вітру гнеться. **Боже милий**

# %%
print ('hello world')
# Out:
# hello world

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### Розділ ####

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is AA1C-4F3E
#
#  Directory of C:\Users\katerynal
#
# 12/05/2025  04:39 PM    <DIR>          .
# 10/16/2023  11:51 AM    <DIR>          ..
# 12/04/2025  02:21 PM    <DIR>          .anaconda
# 12/05/2025  04:40 PM    <DIR>          .conda
# 12/04/2025  02:25 PM                25 .condarc
# 12/04/2025  02:21 PM    <DIR>          .continuum
# 12/05/2025  04:13 PM    <DIR>          .ipynb_checkpoints
# 12/04/2025  11:31 PM    <DIR>          .ipython
# 12/04/2025  02:27 PM    <DIR>          .jupyter
# 06/02/2022  02:00 PM    <DIR>          3D Objects
# 12/04/2025  02:27 PM    <DIR>          Anaconda
# 12/04/2025  02:34 PM    <DIR>          anaconda_projects
# 10/17/2023  08:54 AM    <DIR>          Contacts
# 12/03/2025  09:00 PM    <DIR>          Desktop
# 02/11/2025  06:37 PM    <DIR>          Documents
# 12/04/2025  11:25 PM    <DIR>          Downloads
# 10/17/2023  08:54 AM    <DIR>          Favorites
# 10/17/2023  08:54 AM    <DIR>          Links
# 10/17/2023  08:54 AM    <DIR>          Music
# 08/25/2023  08:56 AM    <DIR>          OneDrive
# 10/17/2023  10:36 AM    <DIR>          Pictures
# 10/17/2023  08:54 AM    <DIR>          Saved Games
# 10/17/2023  08:54 AM    <DIR>          Searches
# 12/04/2025  11:33 PM               628 Untitled.ipynb
# 12/05/2025  02:26 PM             1,617 Untitled1.ipynb
# 12/05/2025  04:39 PM             4,156 Untitled2.ipynb
# 10/17/2023  08:54 AM    <DIR>          Videos
#                4 File(s)          6,426 bytes
#               23 Dir(s)  376,349,442,048 bytes free

# %%
# !cd
# Out:
# C:\Users\katerynal

# %%
s = "hello world!"
print (1+1)
print (2+2)
print (3+3)
print (s)
# Out:
# 2
# 4
# 6
# hello world!

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.sin(np.arange(100))) 
plt.show()
